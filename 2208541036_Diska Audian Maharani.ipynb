# %%
print ('nama saya Diska Audian Maharani')
# Out:
# nama saya Diska Audian Maharani

# %%
print ('tempat tinggal saya di: \nDesa Kesambirampak \nKecamatan Kapongan \nKabupaten Situbondo \nProvinsi Jawa Timur')
# Out:
# tempat tinggal saya di:
# Desa Kesambirampak
# Kecamatan Kapongan
# Kabupaten Situbondo
# Provinsi Jawa Timur

# %%
kemeja_di_lemari = 20
kaos_di_lemari = 10
dress_di_lemari = 8
print (kemeja_di_lemari)
print (kaos_di_lemari)
print (dress_di_lemari)
print (kemeja_di_lemari+kaos_di_lemari+dress_di_lemari)
# Out:
# 20
# 10
# 8
# 38

# %%
nama = input ('nama ')
nim = input ('nim ')
prodi = input ('prodi ')
fakultas = input ('fakultas ')
universitas = input ('universitas ')
angkatan = input ('angkatan ')
# Out:
# nama Diska Audian Maharani
# nim 2208541036
# prodi Matematika
# fakultas MIPA
# universitas Udayana
# angkatan 2022

# %%
harga_baju = input ('Berapakah harga baju yang dibeli? ')
harga_celana = input ('Berapakah harga celana yang dibeli? ')
total_belanja = int(harga_baju) + int(harga_celana)
print ('total belanja adalah ' + str (total_belanja))
# Out:
# Berapakah harga baju yang dibeli? 80000
# Berapakah harga celana yang dibeli? 98000
# total belanja adalah 178000

# %%
bil_1 = int (input('masukkan bilangan 1= '))
bil_2 = int (input('masukkan bilangan 2= '))
print ('hasil operasinya: ')
kali = bil_1*bil_2
kurang = bil_1-bil_2
tambah = bil_1+bil_2
modulo = bil_1%bil_2
print ('hasil kali = ', kali)
print ('hasil kurang = ', kurang)
print ('hasil tambah = ', tambah)
print ('hasil modulo = ', modulo)
# Out:
# masukkan bilangan 1= 90
# masukkan bilangan 2= 80
# hasil operasinya:
# hasil kali =  7200
# hasil kurang =  10
# hasil tambah =  170
# hasil modulo =  10

# %%
#menginput jari jari dan tinggi kerucut
r = int (input('jari jari = '))
t = int (input('tinggi = '))

#diketahui phi adalah
phi = 3.14

#rumus volume kerucut
volume = 1/3*phi*r**2*t

#menampilkan hasil perhitungan
print('volume kerucut adalah ', volume)
# Out:
# jari jari = 80
# tinggi = 200
# volume kerucut adalah  1339733.3333333333

# %%
#menginput alas dan tinggi segitiga
alas = float (input('tulis alas segitiga: '))
tinggi = float (input('tulis tinggi segitiga: '))

#hitung luas segitiga
luas = (alas*tinggi)/2

#menampilkan hasil perhitungan
print ('luas segitiga adalah %0.2f' %luas)
# Out:
# tulis alas segitiga: 6
# tulis tinggi segitiga: 12
# luas segitiga adalah 36.00

# %%
nama = 'ainun'
nilai = "80"
matkul = 'statistika'
ujian = 'UTS'
print (nama + ' mendapatkan nilai ' + nilai + ' di matkul ' + matkul + ' dalam ' + ujian)
# Out:
# ainun mendapatkan nilai 80 di matkul statistika dalam UTS

# %%
print (f'{nama} mendapatkan nilai {nilai} di matkul {matkul} dalam {ujian}')
# Out:
# ainun mendapatkan nilai 80 di matkul statistika dalam UTS

# %%
a = True
b = False

#logika and
c = a and b
print ('True and False = ',c)

#logika OR
c = a or b
print ('True or False = ',c)

#logika not
c = not a
print ('not True = ', c)
# Out:
# True and False =  False
# True or False =  True
# not True =  False
