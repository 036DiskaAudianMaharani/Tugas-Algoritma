# %%
#Tugas III
#Senin, 20 Maret 2023
#belajar membuat String Index

ramadhan = 'adalah bulan yang mulia'

# %%
#string indeks dimulai dengan 0 dan diakhiri huruf ke 20 dengan spasi dihitung
print (ramadhan[0:20])
# Out:
# adalah bulan yang mu

# %%
#string indeks dimulai dengan huruf ke 10 dan diakhiri huruf ke 21 dengan spasi dihitung
print (ramadhan[10:21])
# Out:
# an yang mul

# %%
#string indeks dimulai dengan 0 dan diakhiri huruf ke 7 dengan spasi dihitung
print (ramadhan[0:7])
# Out:
# adalah

# %%
#string huruf dimulai dengan huruf ke 2 (dengan spasi dihitung)
#dengan loncatan sebanyak 10 (dengan spasi dihitung()
#diakhiri huruf ke 2 (dengan spasi dihitung)
print (ramadhan[0:2:10])
# Out:
# a

# %%
#string huruf dimulai dengan index ke 5 (dengan spasi dihitung)
#diakhiri huruf ke 20 (dengan spasi dihitung)
#dengan loncatan sebanyak 5 (dengan spasi dihitung)
print (ramadhan[5:20:5])
# Out:
# han

# %%
#error karena tidak diisi (tidak dipanggil) kata ramadhan
print ([2:10])
# Out:
#   File "<ipython-input-17-b348bdcbeb13>", line 2
#     print ([2:10])
#              ^
# SyntaxError: invalid syntax

# %%
#Belajar membuat String Method

kelahiran = 'Situbondo kota santri'

# %%
#len berfungsi sebagai total pada huruf di atas
print (len(kelahiran))
# Out:
# 21

# %%
#upper berfungsi mengkapitalkan semua huruf
kelahiran.upper ()
# Out:
# 'SITUBONDO KOTA SANTRI'

# %%
#lower berfungsi menjadikan huruf kecil pada semua huruf
kelahiran.lower ()
# Out:
# 'situbondo kota santri'

# %%
#find berfungsi mencari huruf k pada index berapa 
kelahiran.find('kota')
# Out:
# 10

# %%
kelahiran.find('Kota')
# Out:
# -1

# %%
#mengganti kata Situbondo menjadi Kapongan
kelahiran.replace('Situbondo', 'Kapongan')
# Out:
# 'Kapongan kota santri'

# %%
#in berfungsi menghasilkan true atau false
print ('Situbondo' in kelahiran)
# Out:
# True

# %%
print ('situbondo' in kelahiran)
# Out:
# False

# %%
#Belajar operasi matematika di python

#penjumlahan menggunakan simbol (+)
print (5+10)
print (13+150)
print (25+6+3)
#augmented operator
#artinya x=x+1
x= 5
x+= 2
print (x)
# Out:
# 15
# 163
# 34
# 7

# %%
#pengurangan menggunakan simbol (-)
print (5-10)
print (1867-17-20)
# Out:
# -5
# 1830

# %%
#perkalian menggunakan simbol (*)
print (50*50)
print (2*3*9)
# Out:
# 2500
# 54

# %%
#pembagian menggunakan simbol (/)
print (10/2)
print (15/5/3)
print (20/15)
# Out:
# 5.0
# 1.0
# 1.3333333333333333

# %%
#pembulatan pembagian menggunakan simbol (//)
print (15//2)
print (123//40)
# Out:
# 7
# 3

# %%
#modulo/sisa menggunakan simbol (%)
print (30%6)
print (15%2)
# Out:
# 0
# 1

# %%
#pemangkatan menggunakan simbol (**)
print (15**3)
print (6**2)
print (1345*16)
print (10**2)
# Out:
# 3375
# 36
# 21520
# 100

# %%
#Belajar perbandingan
#dengan pernyataan true dan false

#lebih besar menggunakan simbol (>)
y = 1567>1245
print (y)
y= 18736367426>889178178
print (y)
# Out:
# True
# True

# %%
#lebih kecil menggunakan simbol (<)
a = 55 < 9086
print (a)
a= 116578 < 1891876
print (a)
# Out:
# True
# True

# %%
#lebih besar sama dengan menggunakan simbol (>=)
b = 3 >=3
print (b)
b = 6565 >= 1689766
print (b)
# Out:
# True
# False

# %%
#lebih kecil sama dengan disimbolkan (<=)
x = 56 <= 5
print (x)
x= 5676 <= 777
print (x)
# Out:
# False
# False

# %%
#sama dengan disimbolkan dengan (==)
c= 676 == 976
print (c)
c= 45678 == 45678
print (c)
# Out:
# False
# True

# %%
#tidak sama dengan disimbolkan dengan (!=)
y = 1212!=678
print (y)
y= 78 != 78
print (y)
# Out:
# True
# False

# %%
#belajar Logika

#operator or akan bernilai benar jika salah satunya True
#
nilai_algoritma_fitri = 85
nilai_algoritma_cinta = 90
nilai_algoritma_nabila = 88
print (nilai_algoritma_fitri < 60 or nilai_algoritma_cinta < 95 )
# Out:
# True

# %%
nilai_algoritma_fitri = 85
nilai_algoritma_cinta = 90
nilai_algoritma_nabila = 88
print (nilai_algoritma_fitri < 60 and nilai_algoritma_cinta < 95 )
# Out:
# False
